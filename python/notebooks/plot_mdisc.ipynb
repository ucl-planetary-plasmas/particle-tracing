# %% [markdown]
# # Dependencies

# %%
from pymagdisc.data.load_data import load_model
from pymagdisc.vis.plot_mdisc import plot_2d_cmp_exp_Pcold, plot_2d_cmp_exp_jphi
from pymagdisc import config
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
MD_CMP = load_model(f'{config.PATH_TO_DATA}jup_mdisc_kh3e7_rmp60fix.mat');
MD_EXP = load_model(f'{config.PATH_TO_DATA}jup_mdisc_kh3e7_rmp90fix.mat');

# %% [markdown]
# # Plot reference disc models

# %%
plot_2d_cmp_exp_Pcold(MD_CMP, MD_EXP)

# %% [markdown]
# # PLot reference disc current models

# %%
plot_2d_cmp_exp_jphi(MD_CMP, MD_EXP)
