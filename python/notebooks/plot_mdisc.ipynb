# %% [markdown]
# # Dependencies

# %%
import warnings

from pymagdisc import config
from pymagdisc.data.load_data import load_model
from pymagdisc.vis.plot_mdisc import plot_2d_cmp_exp_jphi, plot_2d_cmp_exp_Pcold

warnings.filterwarnings("ignore")

# %% [markdown]
# # Load data

# %%
MD_CMP = load_model(f"{config.PATH_TO_DATA}jup_mdisc_kh3e7_rmp60.mat")
MD_EXP = load_model(f"{config.PATH_TO_DATA}jup_mdisc_kh3e7_rmp90.mat");

# %% [markdown]
# # Plot reference disc models

# %%
plot_2d_cmp_exp_Pcold(MD_CMP, MD_EXP)

# %% [markdown]
# # PLot reference disc current models

# %%
plot_2d_cmp_exp_jphi(MD_CMP, MD_EXP)
